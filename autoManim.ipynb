# %%
import os 
import getpass
from openai import OpenAI

# %%
if not os.environ.get("OPENROUTER_API_KEY"):
    os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter Your OpenRouter API Key here:")

# %%
# %pip install langchain
# Out:
# Requirement already satisfied: langchain in d:\automanim\venv\lib\site-packages (0.3.25)
# Requirement already satisfied: PyYAML>=5.3 in d:\automanim\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\automanim\venv\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\automanim\venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: requests<3,>=2 in d:\automanim\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\automanim\venv\lib\site-packages (from langchain) (2.11.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\automanim\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in d:\automanim\venv\lib\site-packages (from langchain) (0.3.42)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in d:\automanim\venv\lib\site-packages (from langchain) (0.3.59)
# Requirement already satisfied: typing-extensions>=4.7 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\automanim\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: certifi in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: anyio in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\automanim\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\automanim\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\automanim\venv\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet>=1 in d:\automanim\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\automanim\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\automanim\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\autoManim\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install "langchain[openai]"
# Out:
# Requirement already satisfied: langchain[openai] in d:\automanim\venv\lib\site-packages (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (2.0.40)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (0.3.59)
# Requirement already satisfied: requests<3,>=2 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (2.11.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (0.3.42)
# Requirement already satisfied: PyYAML>=5.3 in d:\automanim\venv\lib\site-packages (from langchain[openai]) (6.0.2)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.16-py3-none-any.whl (62 kB)
# Requirement already satisfied: packaging<25,>=23.2 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain[openai]) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain[openai]) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain[openai]) (4.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\automanim\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain[openai]) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\automanim\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain[openai]) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain[openai]) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain[openai]) (3.10.18)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain[openai]) (0.23.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\automanim\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain[openai]) (0.28.1)
# Requirement already satisfied: idna in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (3.10)
# Requirement already satisfied: certifi in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (2025.4.26)
# Requirement already satisfied: anyio in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in d:\automanim\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\automanim\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\automanim\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\automanim\venv\lib\site-packages (from requests<3,>=2->langchain[openai]) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\automanim\venv\lib\site-packages (from requests<3,>=2->langchain[openai]) (3.4.2)
# Requirement already satisfied: greenlet>=1 in d:\automanim\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain[openai]) (3.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\automanim\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\automanim\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain[openai]) (1.3.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in d:\automanim\venv\lib\site-packages (from langchain-openai->langchain[openai]) (1.78.1)
# Collecting tiktoken<1,>=0.7
#   Using cached tiktoken-0.9.0-cp310-cp310-win_amd64.whl (894 kB)
# Requirement already satisfied: tqdm>4 in d:\automanim\venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai->langchain[openai]) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\automanim\venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai->langchain[openai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\automanim\venv\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai->langchain[openai]) (0.9.0)
# Collecting regex>=2022.1.18
#   Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
# Requirement already satisfied: colorama in d:\automanim\venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain-openai->langchain[openai]) (0.4.6)
# Installing collected packages: regex, tiktoken, langchain-openai
# Successfully installed langchain-openai-0.3.16 regex-2024.11.6 tiktoken-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\autoManim\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import langchain
from langchain_openai.chat_models.base import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.chains import LLMChain

# %%
system_template = """
You are “AutoManim Assistant,” an AI expert whose *only* job is to generate complete, runnable Python scripts for 2D animations using the Manim Community v0.19 library. Never output HTML, CSS, or any other language.

Rules:
1. **Always** wrap your entire response in a single ```python``` code block.
2. The script must include:
   - `from manim import *`  
   - A `class MyScene(Scene):` definition with a `construct(self)` method implementing the animation steps.  
   - A “main guard” at the bottom to instantiate and render the scene:

    ```python
    if __name__ == "__main__":
        scene = MyScene()
        scene.render()
    ```
3. Name the scene class descriptively (e.g. `ExpandCircle`, `RotateSquare`, etc.).
4. Use clear, idiomatic Manim patterns (e.g. `self.play(...)`, `.animate`, run_time parameters).
5. Do **not** include any prose or comments outside of the code block—unless the user explicitly requests an explanation.
6. If the user’s request is ambiguous, ask a clarifying question instead of guessing.

Example:

User: “Make a circle expand from radius 0 to 2 over 2 seconds and save the output.”  
Assistant:
```python
from manim import *

class ExpandCircle(Scene):
    def construct(self):
        circle = Circle(radius=0)
        self.play(circle.animate.set(radius=2), run_time=2)

if __name__ == "__main__":
    scene = ExpandCircle()
    scene.render()

"""

systemMessage = SystemMessagePromptTemplate.from_template(system_template)

human_template = "Question : {question}"
human_message = HumanMessagePromptTemplate.from_template(human_template)

chat_prompt = ChatPromptTemplate.from_messages([systemMessage,human_message])

llm = ChatOpenAI(
    openai_api_key = os.environ.get("OPENROUTER_API_KEY"),
    openai_api_base = "https://openrouter.ai/api/v1",
    model_name = "deepseek/deepseek-prover-v2:free"
)

llm_chain = LLMChain(prompt = chat_prompt , llm = llm)
question = """
Create a complete, runnable Manim Community v0.19 Python script named `BouncingBallsInCircle` that does the following:

1. Draws a large static circle boundary (radius 3) centered on screen.
2. Spawns N=10 small solid balls (radius 0.2) at random positions _inside_ the big circle, each with a random initial velocity vector.
3. Simulates elastic collisions:
   - Between each ball and the circular wall: reflect the velocity vector when a ball hits the boundary.
   - Between balls: exchange velocities on overlap (perfectly elastic).
4. Uses Manim’s updaters or a custom `PhysicsBall` class so that:
   - Positions are updated frame‑by‑frame according to velocity and `dt`.
   - Velocities are adjusted on collisions.
5. Runs the simulation for `run_time=10` seconds at 60 FPS.
6. Includes all imports, a descriptive `class BouncingBallsInCircle(Scene):` with a `construct()` method, and a `if __name__ == "__main__": ...` guard to render and save the video.
7. Wraps the entire response in one ```python``` code block—no extra prose.

Make sure the balls never escape the circle and that collisions conserve speed.  
"""
print(llm_chain.run({"question" : question}))
# Out:
# ```python
# from manim import *
# import numpy as np
# from numpy.random import uniform, randint
#
# class PhysicsBall:
#     def __init__(self, scene, radius=0.2, color=BLUE, boundary_radius=3, speed=1):
#         self.scene = scene
#         self.radius = radius
#         self.color = color
#         self.boundary_radius = boundary_radius
#         self.speed = speed
#         self.position = self.random_position()
#         self.velocity = self.random_velocity()
#         self.mobject = Circle(radius=radius, color=color).move_to(self.position)
#         self.scene.add(self.mobject)
#         self.mobject.add_updater(self.update)
#
#     def random_position(self):
#         angle = uniform(0, 2 * np.pi)
#         radius = uniform(0, self.boundary_radius - self.radius)
#         return np.array([radius * np.cos(angle), radius * np.sin(angle), 0])
#
#     def random_velocity(self):
#         angle = uniform(0, 2 * np.pi)
#         return self.speed * np.array([np.cos(angle), np.sin(angle), 0])
#
#     def update(self, mobject, dt):
#         self.position += self.velocity * dt
#         self.check_boundary_collision()
#         self.mobject.move_to(self.position)
#
#     def check_boundary_collision(self):
#         distance = np.linalg.norm(self.position)
#         if distance + self.radius >= self.boundary_radius:
#             normal = self.position / distance
#             self.velocity -= 2 * np.dot(self.velocity, normal) * normal
#             self.position = (self.boundary_radius - self.radius) * normal
#
#     def check_ball_collision(self, other):
#         distance = np.linalg.norm(self.position - other.position)
#         if distance < self.radius + other.radius:
#             normal = (self.position - other.position) / distance
#             tangent = np.array([-normal[1], normal[0], 0])
#             v1n = np.dot(self.velocity, normal)
#             v1t = np.dot(self.velocity, tangent)
#             v2n = np.dot(other.velocity, normal)
#             v2t = np.dot(other.velocity, tangent)
#             self.velocity = v2n * normal + v1t * tangent
#             other.velocity = v1n * normal + v2t * tangent
#
# class BouncingBallsInCircle(Scene):
#     def construct(self):
#         boundary = Circle(radius=3, color=WHITE)
#         self.add(boundary)
#         num_balls = 10
#         balls = [PhysicsBall(self, boundary_radius=3, speed=uniform(0.5, 1.5)) for _ in range(num_balls)]
#         def update_balls(dt):
#             for i in range(num_balls):
#                 for j in range(i + 1, num_balls):
#                     balls[i].check_ball_collision(balls[j])
#         self.add_updater(update_balls)
#         self.wait(10)
#
# if __name__ == "__main__":
#     scene = BouncingBallsInCircle()
#     scene.render()
# ```
